# %%
import os

# %%
import pandas as pd

# %%
df = pd.read_csv('vietnamese_sentences.csv')
df.head()
# Out:
#                                             sentence
# 0  Hôm nay trời nắng đẹp, tôi quyết định đi bộ ra...
# 1  Cô ấy vừa đăng một tấm ảnh mới trên Instagram ...
# 2  Điện thoại thông minh đã trở thành vật bất ly ...
# 3  Chúng ta nên uống đủ nước mỗi ngày để giữ sức ...
# 4  Tối qua tôi xem một bộ phim Hàn Quốc rất cảm đ...

# %%
list_sentences = df['sentence'].astype(str).tolist()
list_sentences[:5]
# Out:
# ['Hôm nay trời nắng đẹp, tôi quyết định đi bộ ra công viên.',
#  'Cô ấy vừa đăng một tấm ảnh mới trên Instagram và nhận được nhiều lượt thích.',
#  'Điện thoại thông minh đã trở thành vật bất ly thân của nhiều người.',
#  'Chúng ta nên uống đủ nước mỗi ngày để giữ sức khỏe.',
#  'Tối qua tôi xem một bộ phim Hàn Quốc rất cảm động.']

# %%
with open('vietnamese_sentences.txt', 'w', encoding='utf-8') as f:
    f.write('\n'.join(list_sentences) + '\n')
